# %%
import os

folder_path = "images/drawings/"
gallery_html = ""

# 遍历文件夹中的文件
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        image_path = os.path.join(folder_path, filename)
        gallery_html += f'<img src="{image_path}">'
# 生成HTML文件
html_content = f"""
<!DOCTYPE html>
<html>
<head>
  <style>
    .gallery {{
      display: flex;
      flex-wrap: wrap;
      justify-content: center;
      align-items: center;
      gap: 20px;
      max-width: 800px;
      margin: 0 auto;
    }}
    .gallery img {{
      width: 200px;
      height: 200px;
      object-fit: cover;
    }}
  </style>
</head>
<body>
  <div class="gallery">
    {gallery_html}
  </div>
</body>
</html>
"""

# 将HTML内容保存到文件
with open("gallery.html", "w") as file:
    file.write(html_content)

# %%
import os

# 指定图片文件夹路径
folder_path = "images/photos/"

# 获取文件夹中的图片文件名列表
image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f)) and f.endswith(('.jpg', '.jpeg', '.png'))]

# 生成HTML代码
html_code = '<div class="gallery">\n'
for i, image_file in enumerate(image_files):
    image_id = "image" + str(i+1)
    image_src = os.path.join(folder_path, image_file)
    html_code += f'  <img id="{image_id}" src="{image_src}">\n'
html_code += "</div>"

# 输出HTML代码
print(html_code)
# Out:
# <div class="gallery">
#   <img id="image1" src="images/photos/4211693783146_.pic.jpg">
#   <img id="image2" src="images/photos/IMG_3131.jpg">
#   <img id="image3" src="images/photos/4861698004227_.pic.jpg">
#   <img id="image4" src="images/photos/4461696704384_.pic.jpg">
#   <img id="image5" src="images/photos/4531696704394_.pic.jpg">
#   <img id="image6" src="images/photos/4661696705147_.pic.jpg">
#   <img id="image7" src="images/photos/4321696704375_.pic.jpg">
#   <img id="image8" src="images/photos/4391696704379_.pic.jpg">
#   <img id="image9" src="images/photos/4571696704402_.pic.jpg">
#   <img id="image10" src="images/photos/3341691942368_.pic.jpg">
#   <img id="image11" src="images/photos/4581696704406_.pic.jpg">
#   <img id="image12" src="images/photos/4621696705144_.pic.jpg">
#   <img id="image13" src="images/photos/4691696705148_.pic.jpg">
#   <img id="image14" src="images/photos/4231693783148_.pic.jpg">
#   <img id="image15" src="images/photos/4781696705544_.pic.jpg">
# ...

# %%
import os

folder_path = "images/photos/"
gallery_html = ""

# 遍历文件夹中的文件
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        image_path = os.path.join(folder_path, filename)
        gallery_html += f'<img src="{image_path}">'
# 生成HTML文件
html_content = f"""
<!DOCTYPE html>
<html>
<head>
  <style>
    .gallery {{
      display: flex;
      flex-wrap: wrap;
      justify-content: center;
      align-items: center;
      gap: 20px;
      max-width: 800px;
      margin: 0 auto;
    }}
    .gallery img {{
      width: 200px;
      height: 200px;
      object-fit: cover;
    }}
  </style>
</head>
<body>
  <div class="gallery">
    {gallery_html}
  </div>
</body>
</html>
"""

# 将HTML内容保存到文件
with open("gallery.html", "w") as file:
    file.write(html_content)

# %%
import os

folder_path = "images/sicklepot/"
gallery_html = ""

# 遍历文件夹中的文件
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        image_path = os.path.join(folder_path, filename)
        gallery_html += f'<img src="{image_path}">'
# 生成HTML文件
html_content = f"""
<!DOCTYPE html>
<html>
<head>
  <style>
    .gallery {{
      display: flex;
      flex-wrap: wrap;
      justify-content: center;
      align-items: center;
      gap: 20px;
      max-width: 800px;
      margin: 0 auto;
    }}
    .gallery img {{
      width: 200px;
      height: 200px;
      object-fit: cover;
    }}
  </style>
</head>
<body>
  <div class="gallery">
    {gallery_html}
  </div>
</body>
</html>
"""

# 将HTML内容保存到文件
with open("gallery.html", "w") as file:
    file.write(html_content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 7>()
#       4 gallery_html = ""
#       6 # 遍历文件夹中的文件
# ----> 7 for filename in os.listdir(folder_path):
#       8     if filename.endswith(".jpg") or filename.endswith(".png"):
#       9         image_path = os.path.join(folder_path, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images/sicklepot/'

# %%
import os
from PIL import Image

def compress_images(input_dir, output_dir, quality):
    # 创建输出文件夹
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # 遍历输入文件夹中的所有文件
    for filename in os.listdir(input_dir):
        if filename.endswith('.jpg'):
            # 构建输入和输出文件的路径
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            # 打开图片并进行压缩
            with Image.open(input_path) as img:
                img.save(output_path, 'JPEG', quality=quality)

            print(f'压缩成功: {output_path}')

# 输入文件夹路径
input_dir = 'images/photos/'

# 输出文件夹路径
output_dir = 'images/compressed/'

# 压缩质量（0-100），值越低压缩率越高
quality = 1

# 调用函数进行压缩
compress_images(input_dir, output_dir, quality)
# Out:
# 压缩成功: images/compressed/6601713073958_.pic.jpg
# 压缩成功: images/compressed/5681709044973_.pic.jpg
# 压缩成功: images/compressed/6441713072488_.pic.jpg
# 压缩成功: images/compressed/5581709044894_.pic.jpg
# 压缩成功: images/compressed/6421713072485_.pic.jpg
# 压缩成功: images/compressed/6511713072499_.pic.jpg
# 压缩成功: images/compressed/6401713072481_.pic.jpg
# 压缩成功: images/compressed/6711713073974_.pic.jpg
# 压缩成功: images/compressed/6501713072496_.pic.jpg
# 压缩成功: images/compressed/6581713073955_.pic.jpg
# 压缩成功: images/compressed/6721713073975_.pic.jpg
# 压缩成功: images/compressed/6741713073979_.pic.jpg
# 压缩成功: images/compressed/5721709045243_.pic.jpg
# 压缩成功: images/compressed/5571709044886_.pic.jpg
# 压缩成功: images/compressed/6291713072466_.pic.jpg
# 压缩成功: images/compressed/6331713072472_.pic.jpg
# 压缩成功: images/compressed/5741709045245_.pic.jpg
# 压缩成功: images/compressed/6411713072484_.pic.jpg
# 压缩成功: images/compressed/6351713072475_.pic.jpg
# 压缩成功: images/compressed/6461713072491_.pic.jpg
# ...
